# %%
# %cd ~
# %mkdir content
# %cd /content

# !git clone -b v1.8 https://github.com/camenduru/text-generation-webui
# %cd text-generation-webui
# !pip install -r requirements.txt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/resolve/main/model-00001-of-00002.safetensors -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o model-00001-of-00002.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/resolve/main/model-00002-of-00002.safetensors -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o model-00002-of-00002.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/model.safetensors.index.json -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o model.safetensors.index.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/special_tokens_map.json -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/resolve/main/tokenizer.model -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o tokenizer.model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/tokenizer_config.json -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/config.json -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/generation_config.json -d /content/text-generation-webui/models/Llama-2-7b-chat-hf -o generation_config.json

# %cd /content/text-generation-webui
# !python server.py --share --chat --model /content/text-generation-webui/models/Llama-2-7b-chat-hf
# Out:
# /Users/a667207
# [Errno 2] No such file or directory: '/content'
# /Users/a667207
# Cloning into 'text-generation-webui'...
# remote: Enumerating objects: 9753, done.
# remote: Counting objects: 100% (325/325), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 9753 (delta 189), reused 230 (delta 137), pack-reused 9428
# Receiving objects: 100% (9753/9753), 3.29 MiB | 5.60 MiB/s, done.
# Resolving deltas: 100% (6510/6510), done.
# /Users/a667207/text-generation-webui
# Collecting git+https://github.com/huggingface/peft@03eb378eb914fbee709ff7c86ba5b1d033b89524 (from -r requirements.txt (line 22))
#   Cloning https://github.com/huggingface/peft (to revision 03eb378eb914fbee709ff7c86ba5b1d033b89524) to /private/var/folders/tr/51y6qz611j73483c4shsv921b0m7rt/T/pip-req-build-_f3ho2m8
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft /private/var/folders/tr/51y6qz611j73483c4shsv921b0m7rt/T/pip-req-build-_f3ho2m8
#   Running command git rev-parse -q --verify 'sha^03eb378eb914fbee709ff7c86ba5b1d033b89524'
#   Running command git fetch -q https://github.com/huggingface/peft 03eb378eb914fbee709ff7c86ba5b1d033b89524
#   Running command git checkout -q 03eb378eb914fbee709ff7c86ba5b1d033b89524
#   Resolved https://github.com/huggingface/peft to commit 03eb378eb914fbee709ff7c86ba5b1d033b89524
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Ignoring bitsandbytes: markers 'platform_system == "Windows"' don't match your environment
# Ignoring llama-cpp-python: markers 'platform_system == "Windows"' don't match your environment
# Ignoring auto-gptq: markers 'platform_system == "Windows"' don't match your environment
# Ignoring auto-gptq: markers 'platform_system == "Linux" and platform_machine == "x86_64"' don't match your environment
# Ignoring exllama: markers 'platform_system == "Windows"' don't match your environment
# Ignoring exllama: markers 'platform_system == "Linux" and platform_machine == "x86_64"' don't match your environment
# Requirement already satisfied: accelerate==0.21.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: colorama in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: datasets in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2.13.1)
# Requirement already satisfied: einops in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: fastapi==0.95.2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.95.2)
# Requirement already satisfied: flexgen==0.1.7 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: gradio_client==0.2.5 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: gradio==3.33.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.33.1)
# Requirement already satisfied: markdown in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (3.4.3)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.24.3)
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.5.3)
# Requirement already satisfied: Pillow>=9.5.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (10.0.0)
# Requirement already satisfied: pyyaml in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (6.0)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (2.29.0)
# Requirement already satisfied: safetensors==0.3.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.3.1)
# Requirement already satisfied: sentencepiece in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.1.99)
# Requirement already satisfied: tqdm in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (4.65.0)
# Requirement already satisfied: scipy in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.10.1)
# Requirement already satisfied: tensorboard in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (2.13.0)
# Requirement already satisfied: wandb in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (0.15.5)
# Requirement already satisfied: transformers==4.30.2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (4.30.2)
# Requirement already satisfied: bitsandbytes==0.40.2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (0.40.2)
# Requirement already satisfied: llama-cpp-python==0.1.72 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (0.1.72)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from fastapi==0.95.2->-r requirements.txt (line 5)) (1.10.12)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from fastapi==0.95.2->-r requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: pulp in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from flexgen==0.1.7->-r requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: attrs in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from flexgen==0.1.7->-r requirements.txt (line 6)) (22.1.0)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio_client==0.2.5->-r requirements.txt (line 7)) (2023.6.0)
# Requirement already satisfied: httpx in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio_client==0.2.5->-r requirements.txt (line 7)) (0.24.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio_client==0.2.5->-r requirements.txt (line 7)) (0.16.4)
# Requirement already satisfied: typing-extensions in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio_client==0.2.5->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: websockets in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio_client==0.2.5->-r requirements.txt (line 7)) (11.0.3)
# Requirement already satisfied: aiofiles in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (22.1.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (3.8.5)
# Requirement already satisfied: altair>=4.2.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (5.0.1)
# Requirement already satisfied: ffmpy in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (0.3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: markupsafe in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (0.3.3)
# Requirement already satisfied: orjson in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (3.9.2)
# Requirement already satisfied: pydub in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (2.15.1)
# Requirement already satisfied: python-multipart in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (0.0.6)
# Requirement already satisfied: semantic-version in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gradio==3.33.1->-r requirements.txt (line 8)) (0.23.1)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from transformers==4.30.2->-r requirements.txt (line 21)) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from transformers==4.30.2->-r requirements.txt (line 21)) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from transformers==4.30.2->-r requirements.txt (line 21)) (0.13.3)
# Requirement already satisfied: diskcache>=5.6.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from llama-cpp-python==0.1.72->-r requirements.txt (line 25)) (5.6.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 3)) (12.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 3)) (0.3.6)
# Requirement already satisfied: xxhash in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: multiprocess in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 3)) (0.70.14)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 11)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 11)) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from requests->-r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from requests->-r requirements.txt (line 14)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from requests->-r requirements.txt (line 14)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from requests->-r requirements.txt (line 14)) (2022.6.15)
# Requirement already satisfied: absl-py>=0.4 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (1.0.0)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (4.23.4)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (67.8.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 19)) (0.38.4)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (8.1.6)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (3.1.32)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (1.28.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (0.4.0)
# Requirement already satisfied: pathtools in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (0.1.2)
# Requirement already satisfied: setproctitle in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (1.3.2)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from wandb->-r requirements.txt (line 20)) (1.4.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from altair>=4.2.0->gradio==3.33.1->-r requirements.txt (line 8)) (4.17.3)
# Requirement already satisfied: toolz in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from altair>=4.2.0->gradio==3.33.1->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: six>=1.4.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 20)) (1.16.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from aiohttp->gradio==3.33.1->-r requirements.txt (line 8)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from aiohttp->gradio==3.33.1->-r requirements.txt (line 8)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from aiohttp->gradio==3.33.1->-r requirements.txt (line 8)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from aiohttp->gradio==3.33.1->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from aiohttp->gradio==3.33.1->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 20)) (4.0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 19)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 19)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.33.1->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.33.1->-r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi==0.95.2->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.21.0->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.21.0->-r requirements.txt (line 1)) (2.8.4)
# Requirement already satisfied: h11>=0.8 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio==3.33.1->-r requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from httpx->gradio_client==0.2.5->-r requirements.txt (line 7)) (0.17.3)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from httpx->gradio_client==0.2.5->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from matplotlib->gradio==3.33.1->-r requirements.txt (line 8)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from matplotlib->gradio==3.33.1->-r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from matplotlib->gradio==3.33.1->-r requirements.txt (line 8)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from matplotlib->gradio==3.33.1->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from matplotlib->gradio==3.33.1->-r requirements.txt (line 8)) (3.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 20)) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.33.1->-r requirements.txt (line 8)) (0.18.0)
# Requirement already satisfied: uc-micro-py in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.33.1->-r requirements.txt (line 8)) (1.0.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 19)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-
Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=sGFCGZ2gBVwUGVxhss8Hx7SJ21o2xw75Xw8Pdrq33a6RqF7zXc-A0hcqV7jNmwX8T4HCdyEaAOuCi8b6oNy-LfoKeN8xNkjEF5m6RsHmbxQEOMuvLA5tubzsQrt4--Hh66okz91ToxDd9cxDoApu9efL3JQGXk9PLa%7EelWRe8mc1MNyiTD7QcGZZJFF8SyxxMxIbwLQ--K70wTSyC1xLLYGOBGh9Ze-5ouPKelmvVV8xh0tPNCV%7EboDOtwFtG7UZiWvoPpPZOYT2ekdxBgTQenjnhxgSkP5i7rT5WZMuuOM5MxRKSsdzIQL5isOs8WxUN6Nq44v%7Eo-0fslAvdlbvDQ__&Key-Pair-Id=KVTP0A1DKRTAX
#   -> [RequestGroup.cc:761] errorCode=18 Download aborted.
#   -> [util.cc:1951] errNum=30 errorCode=18 Failed to make the directory /content/text-generation-webui/models/Llama-2-7b-chat-hf, cause: Read-only file system
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c5ba31|ERR |       0B/s|/content/text-generation-webui/models/Llama-2-7b-chat-hf/tokenizer.model
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/27 13:32:34 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/tokenizer_config.json
# Exception: [AbstractCommand.cc:403] errorCode=18 URI=https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/tokenizer_config.json
#   -> [RequestGroup.cc:761] errorCode=18 Download aborted.
#   -> [util.cc:1951] errNum=30 errorCode=18 Failed to make the directory /content/text-generation-webui/models/Llama-2-7b-chat-hf, cause: Read-only file system
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8f3079|ERR |       0B/s|/content/text-generation-webui/models/Llama-2-7b-chat-hf/tokenizer_config.json
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/27 13:32:35 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/config.json
# Exception: [AbstractCommand.cc:403] errorCode=18 URI=https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/config.json
#   -> [RequestGroup.cc:761] errorCode=18 Download aborted.
#   -> [util.cc:1951] errNum=30 errorCode=18 Failed to make the directory /content/text-generation-webui/models/Llama-2-7b-chat-hf, cause: Read-only file system
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ed8081|ERR |       0B/s|/content/text-generation-webui/models/Llama-2-7b-chat-hf/config.json
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/27 13:32:36 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/generation_config.json
# Exception: [AbstractCommand.cc:403] errorCode=18 URI=https://huggingface.co/4bit/Llama-2-7b-chat-hf/raw/main/generation_config.json
#   -> [RequestGroup.cc:761] errorCode=18 Download aborted.
#   -> [util.cc:1951] errNum=30 errorCode=18 Failed to make the directory /content/text-generation-webui/models/Llama-2-7b-chat-hf, cause: Read-only file system
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ec82c1|ERR |       0B/s|/content/text-generation-webui/models/Llama-2-7b-chat-hf/generation_config.json
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [Errno 2] No such file or directory: '/content/text-generation-webui'
# /Users/a667207/text-generation-webui
# 2023-07-27 13:32:41 WARNING:The gradio "share link" feature uses a proprietary executable to create a reverse tunnel. Use it with care.
# /opt/homebrew/anaconda3/envs/NLP/lib/python3.10/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# 2023-07-27 13:32:47 INFO:Loading /content/text-generation-webui/models/Llama-2-7b-chat-hf...
# 2023-07-27 13:32:47 ERROR:The path to the model does not exist. Exiting.
# 2023-07-27 13:32:47 INFO:Loading the extension "gallery"...
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://77ae3d723499535d35.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 2023-07-27 13:33:47 INFO:Loading /content/text-generation-webui/models/Llama-2-7b-chat-hf...
# 2023-07-27 13:33:47 ERROR:Failed to load the model.
# Traceback (most recent call last):
#   File "/Users/a667207/text-generation-webui/server.py", line 68, in load_model_wrapper
#     shared.model, shared.tokenizer = load_model(shared.model_name, loader)
#   File "/Users/a667207/text-generation-webui/modules/models.py", line 79, in load_model
#     output = load_func_map[loader](model_name)
#   File "/Users/a667207/text-generation-webui/modules/models.py", line 265, in llamacpp_loader
#     model_file = list(Path(f'{shared.args.model_dir}/{model_name}').glob('*ggml*.bin'))[0]
# IndexError: list index out of range
#
# ^C
# Traceback (most recent call last):
#   File "/Users/a667207/text-generation-webui/server.py", line 1175, in <module>
#     time.sleep(0.5)
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://77ae3d723499535d35.gradio.live
