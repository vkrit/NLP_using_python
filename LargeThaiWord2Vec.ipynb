# %% [markdown]
# # LTW2V: The Large Thai Word2Vec 1.0
#
# GitHub: https://github.com/PyThaiNLP/large-thaiword2vec/tree/main/1.0
#
# GitHub Sponsors: https://github.com/sponsors/wannaphong/ (Thank you!)

# %%
# !wget https://zenodo.org/record/7280277/files/LTW2V_v1.0-window15.bin
# !wget https://zenodo.org/record/7280277/files/LTW2V_v1.0-window5.bin
# Out:
# --2023-07-26 13:11:29--  https://zenodo.org/record/7280277/files/LTW2V_v1.0-window15.bin
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 960468057 (916M) [application/octet-stream]
# Saving to: ‘LTW2V_v1.0-window15.bin’
#
# LTW2V_v1.0-window15 100%[===================>] 915.97M  2.75MB/s    in 34m 10s
#
# 2023-07-26 13:45:41 (457 KB/s) - ‘LTW2V_v1.0-window15.bin’ saved [960468057/960468057]
#
# --2023-07-26 13:45:41--  https://zenodo.org/record/7280277/files/LTW2V_v1.0-window5.bin
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 960468057 (916M) [application/octet-stream]
# Saving to: ‘LTW2V_v1.0-window5.bin’
#
# LTW2V_v1.0-window5.  56%[==========>         ] 521.79M   189KB/s    in 51m 14s
#
# 2023-07-26 14:36:57 (174 KB/s) - Read error at byte 547142648/960468057 (Network is down). Retrying.
#
# --2023-07-26 14:36:58--  (try: 2)  https://zenodo.org/record/7280277/files/LTW2V_v1.0-window5.bin
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# Unable to establish SSL connection.

# %%
from gensim.models import KeyedVectors

# %%
model5 = KeyedVectors.load_word2vec_format('LTW2V_v1.0-window5.bin', binary=True, unicode_errors='ignore')
model15 = KeyedVectors.load_word2vec_format('LTW2V_v1.0-window15.bin', binary=True, unicode_errors='ignore')
# Out:
# WARNING:gensim.models.utils_any2vec:duplicate word 'จริง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ต่าง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ง่าย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เพื่อน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ดี' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ทุก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'บ่อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ค่อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'น้อง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ใคร' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เร็ว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ทั้ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'คล้าย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ทั่ว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตรง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แปลก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ข้าง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แท้' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เรื่อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แมนเชสเตอร์' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ราว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไหน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ล้วน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เงียบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เร็ว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อินเตอร์' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไร' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'วัน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ระยะ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เสมอ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เฉย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เรียบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ติด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เพลิน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อยู่ดี' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อยู่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ว่าง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'นิ่ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'รัว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ห่าง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'รวย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'กล้วย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'พอ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไป' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'รีบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'กัลโช่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'พื้น' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ถี่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แฮร์รี่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หมาด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สมเด็จพระเทพรัตนราชสุดาฯ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เนือง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หยาบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลอย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'บ้า' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แหะ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แสก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'จู่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หลอก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตึง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ทูลเกล้าฯ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ฮือ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เขิน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลวก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เนิ่น' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ป.' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ปรอย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'รุ่น' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'กลาย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ซื่อ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หยก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สลัว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'วอชิงตัน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'คร่าว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หย่อม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หมู' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'โดด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลูก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หวิว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เอื่อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'มิราเคิล' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ครึ่ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ห้วน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แผ่ว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตุ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อาด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หลง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แหง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ยิก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลุ่ม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ศิลป์' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ยิบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แป๊บ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตาดำ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ฮุน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ซึ่ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หึ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แต่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เหยาะ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สุก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เที่ยง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'งู' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ราง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เบาะ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ย้ำ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เงา' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เนิบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เปรย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลิบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'โต้ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เก้' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'พรำ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อองซาน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ก้ม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เนือย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หนาว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ส่ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เร่า' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไหว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ทึม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เรียง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ผิว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตุบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ซิบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตูม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'คิก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ร้อน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เพลา' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'มัว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'วับ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'จด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ปริบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'วับ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตุ่น' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เลา' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลับ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'พระเจ้าวรวงศ์เธอ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เฉื่อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ผับ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สุ่ม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ฉับ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ออด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไล่' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ทิ้ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ท้วม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เลือก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'พระเจ้าวรวงศ์เธอ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'งก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อ่อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แปลบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ป้อม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'รอน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ปัด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ผลุบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เผิน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เหมียว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ป้ำ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ต้อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เฮือก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หยัก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'พราด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ดาด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เหนาะ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ข้าง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตึก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'รุม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'จ้อย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ริก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ปาว' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ติ๋ง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เลือน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'มหาตมะ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'บิน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ข้าม' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หวัด' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ยวบ' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'โทง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ชุ่ย' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตะลอน' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ป่อง' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'งึก' in LTW2V_v1.0-window5.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word '
' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หยุบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หยับ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แมเนเจอร์' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สุ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เรี่ย' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หวย' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เย' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อิด' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เบี้ยว' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เฉาะ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลูกขุน' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แอด' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'โหย่ง' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'กระดุบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หมับ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ถั่น' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อ้อม' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ครือ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ตึ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ออด' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word '' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หงิก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'คั่ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แด่ว' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'งุบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลูกขุน' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เยิบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ยาบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'โชก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ล่ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ไจ้' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ช้า' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อุบอิบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ผล็อย' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หนุบหนับ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หงัก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แพล็บ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เผาะ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'คว้าง' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ก้าบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หริ่ง' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'มุบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หงับ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อั้ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เด่า' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'วาม' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ขึ้น' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'สวะ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'คลั่ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หลัว' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'จั้ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แซ่ด' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หงก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เหม่' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แด็ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ลื้น' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'จ้อก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'เหวย' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'แง่น' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'อึ้ก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ขวาง' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หนุบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หย่อง' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ดี' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'หยวบ' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'ประดัก' in LTW2V_v1.0-window15.bin, ignoring all but first
# WARNING:gensim.models.utils_any2vec:duplicate word 'วับ' in LTW2V_v1.0-window15.bin, ignoring all but first

# %%
print(model5.most_similar("แมว"))
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:1366: RuntimeWarning: overflow encountered in square
#   self.vectors_norm = (self.vectors / sqrt((self.vectors ** 2).sum(-1))[..., newaxis]).astype(REAL)
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:1366: RuntimeWarning: invalid value encountered in square
#   self.vectors_norm = (self.vectors / sqrt((self.vectors ** 2).sum(-1))[..., newaxis]).astype(REAL)
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:1366: RuntimeWarning: invalid value encountered in true_divide
#   self.vectors_norm = (self.vectors / sqrt((self.vectors ** 2).sum(-1))[..., newaxis]).astype(REAL)
# [('สุนัข', 0.8219841718673706), ('กระต่าย', 0.6115573048591614), ('หมา', 0.5916571021080017), ('เหมียว', 0.5654546618461609), ('นกแก้ว', 0.5310787558555603), ('วัว', 0.48688626289367676), ('สุนัขจิ้งจอก', 0.4697234034538269), ('หนอน', 0.4685564637184143), ('สัตว์เลี้ยง', 0.466613233089447), ('ตูบ', 0.46176600456237793)]

# %%
print(model15.most_similar("แมว"))
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:1366: RuntimeWarning: overflow encountered in square
#   self.vectors_norm = (self.vectors / sqrt((self.vectors ** 2).sum(-1))[..., newaxis]).astype(REAL)
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:1366: RuntimeWarning: invalid value encountered in square
#   self.vectors_norm = (self.vectors / sqrt((self.vectors ** 2).sum(-1))[..., newaxis]).astype(REAL)
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py:1366: RuntimeWarning: invalid value encountered in true_divide
#   self.vectors_norm = (self.vectors / sqrt((self.vectors ** 2).sum(-1))[..., newaxis]).astype(REAL)
# [('สุนัข', 0.8111163973808289), ('เหมียว', 0.6194174885749817), ('หมา', 0.6073242425918579), ('กระต่าย', 0.5319966077804565), ('catlovers', 0.522964358329773), ('lovelycat', 0.4707842469215393), ('สัตว์เลี้ยง', 0.46992960572242737), ('ตูบ', 0.46648555994033813), ('catofinstagram', 0.45703423023223877), ('catlover', 0.4486870765686035)]

# %%
print(model5.most_similar("คนดี"))
# Out:
# [('เด็กดี', 0.5665411949157715), ('คนเลว', 0.560202956199646), ('ทำดี', 0.5452004671096802), ('ความดี', 0.5305304527282715), ('คนชั่ว', 0.5280267596244812), ('คนเก่ง', 0.5137535333633423), ('คุณธรรม', 0.5127763748168945), ('มีน้ำใจ', 0.4996899962425232), ('คุณงามความดี', 0.4686824381351471), ('คนใจดี', 0.45809879899024963)]

# %%
print(model15.most_similar("คนดี"))
# Out:
# [('คนเลว', 0.5823886394500732), ('ทำดี', 0.5791871547698975), ('ความดี', 0.5689451694488525), ('คนชั่ว', 0.5556272268295288), ('คุณธรรม', 0.55318284034729), ('เด็กดี', 0.5092697143554688), ('มีน้ำใจ', 0.5069648623466492), ('คนเก่ง', 0.505056619644165), ('คุณงามความดี', 0.501969575881958), ('ศีลธรรม', 0.49732011556625366)]

# %%
# Use gensim ...
